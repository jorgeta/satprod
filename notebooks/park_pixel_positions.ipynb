# %%
import matplotlib.pyplot as plt
import cv2

root = '..'
full_img = cv2.imread(f'{root}/data/img/sat/2019/04/15/11;00;00.png')
marked_img = cv2.imread(f'{root}/data/parks_2018;06;30;15;00;00.png')

grid_img = cv2.imread(f'{root}/data/img/grid/2021/01/01/14;00;00.png', cv2.IMREAD_GRAYSCALE)

# %%
full_img.shape, grid_img.shape
# Out:
# ((780, 1001, 3), (100, 100))

# %% [markdown]
# ## Full grid image

# %%
plt.figure(figsize=(16,16))
plt.imshow(grid_img)
plt.show()

# %%
plt.figure(figsize=(4,4))
plt.imshow(grid_img)
plt.show()

# %% [markdown]
# ## Full image

# %%
plt.figure(figsize=(16,16))
plt.imshow(full_img)
plt.show()

# %% [markdown]
# ## Parks marked

# %%
plt.figure(figsize=(16,16))
plt.imshow(marked_img)
plt.show()

# %% [markdown]
# ## Zoom on park area

# %%
plt.figure(figsize=(16,16))
plt.imshow(full_img[:350,400:750])
plt.show()

# %% [markdown]
# ## Zoom on park area with parks marked

# %%
plt.figure(figsize=(16,16))
plt.imshow(marked_img[:350,400:750])
plt.show()

# %% [markdown]
# - Valsneset: (200, 460)
# - Ytre Vikna: (75, 580)
# - Bessakerfjellet: (135, 590)
# - Skomakerfjellet: (140, 600)
