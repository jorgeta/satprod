# %%
from satprod.data_handlers.img_data import ImgDataset
from satprod.configs.config_utils import read_yaml, TimeInterval, ImgType

# %%
import fire
import os
from datetime import datetime, timedelta
import cv2
import logging
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = ImgDataset(ImgType('grid'))

# %%
n_imgs = len(data)
lst = np.zeros(n_imgs)
for i in range(n_imgs):
    lst[i] = data[i].img[50,50,0]

# %%
plt.plot(lst)
